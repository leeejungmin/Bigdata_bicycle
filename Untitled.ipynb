# %%
import pandas as pd

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
test.head()

import matplotlib.pyplot as plt

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
train.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
sns.distplot(train['count'])
# Out:
# L:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
train["count"] = np.log1p(train["count"])
sns.distplot(train['count'])

# %%
print(test.shape)
# Out:
# (6493, 9)

# %%
train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-3b77fa18a747> in <module>
# ----> 1 train.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-132c85934a2c> in <module>
# ----> 1 train["datetime-year"] = train["datetime"].dt.year
#
# L:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# L:\Anaconda\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# L:\Anaconda\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     322             pass  # we raise an attribute error anyway
#     323
# --> 324         raise AttributeError("Can only use .dt accessor with datetimelike "
#     325                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
train = pd.read_csv("train.csv", parse_dates=["datetime"])

# %%
train["year"] = train["datetime"].dt.year

# %%
train["month"] = train["datetime"].dt.month
train["day"] = train["datetime"].dt.day
train["hour"] = train["datetime"].dt.hour

# %%
print(train.shape)
# Out:
# (10886, 21)

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.drop(['datetime-month','datetime-year','datetime-dayofwek','datetime-day'],axis=1)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# 5     2011-01-01 05:00:00       1        0           0        2   9.84
# 6     2011-01-01 06:00:00       1        0           0        1   9.02
# 7     2011-01-01 07:00:00       1        0           0        1   8.20
# 8     2011-01-01 08:00:00       1        0           0        1   9.84
# 9     2011-01-01 09:00:00       1        0           0        1  13.12
# 10    2011-01-01 10:00:00       1        0           0        1  15.58
# 11    2011-01-01 11:00:00       1        0           0        1  14.76
# 12    2011-01-01 12:00:00       1        0           0        1  17.22
# 13    2011-01-01 13:00:00       1        0           0        2  18.86
# 14    2011-01-01 14:00:00       1        0           0        2  18.86
# 15    2011-01-01 15:00:00       1        0           0        2  18.04
# 16    2011-01-01 16:00:00       1        0           0        2  17.22
# 17    2011-01-01 17:00:00       1        0           0        2  18.04
# 18    2011-01-01 18:00:00       1        0           0        3  17.22
# 19    2011-01-01 19:00:00       1        0           0        3  17.22
# 20    2011-01-01 20:00:00       1        0           0        2  16.40
# 21    2011-01-01 21:00:00       1        0           0        2  16.40
# 22    2011-01-01 22:00:00       1        0           0        2  16.40
# 23    2011-01-01 23:00:00       1        0           0        2  18.86
# 24    2011-01-02 00:00:00       1        0           0        2  18.86
# 25    2011-01-02 01:00:00       1        0           0        2  18.04
# 26    2011-01-02 02:00:00       1        0           0        2  17.22
# 27    2011-01-02 03:00:00       1        0           0        2  18.86
# 28    2011-01-02 04:00:00       1        0           0        2  18.86
# 29    2011-01-02 06:00:00       1        0           0        3  17.22
# ...                   ...     ...      ...         ...      ...    ...
# 10856 2012-12-18 18:00:00       4        0           1        1  15.58
# 10857 2012-12-18 19:00:00       4        0           1        1  15.58
# 10867  14.395        75     6.0032       2          29     31
# 10868  12.880        75     6.0032       3         109    112
# 10869  13.635        75     8.9981       3         360    363
# 10870  12.880        87     7.0015      13         665    678
# 10871  14.395        75     7.0015       8         309    317
# 10872  16.665        70     7.0015      17         147    164
# 10873  20.455        54    15.0013      31         169    200
# 10874  20.455        54    19.0012      33         203    236
# 10875  21.210        50    12.9980      30         183    213
# 10876  21.210        50    12.9980      33         185    218
# 10877  21.210        50    19.0012      28         209    237
# 10878  21.210        50    23.9994      37         297    334
# 10879  20.455        50    26.0027      26         536    562
# 10880  19.695        50    23.9994      23         546    569
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
#        datetime-dayofweek  datetime-hour  month  day  hour
# 0                       5              0      1    1     0
# 1                       5              1      1    1     1
# 2                       5              2      1    1     2
# 3                       5              3      1    1     3
# 4                       5              4      1    1     4
# 5                       5              5      1    1     5
# 6                       5              6      1    1     6
# 7                       5              7      1    1     7
# 8                       5              8      1    1     8
# 9                       5              9      1    1     9
# 10                      5             10      1    1    10
# 11                      5             11      1    1    11
# 12                      5             12      1    1    12
# 13                      5             13      1    1    13
# 14                      5             14      1    1    14
# 15                      5             15      1    1    15
# 16                      5             16      1    1    16
# 17                      5             17      1    1    17
# 18                      5             18      1    1    18
# 19                      5             19      1    1    19
# 20                      5             20      1    1    20
# 21                      5             21      1    1    21
# 22                      5             22      1    1    22
# 23                      5             23      1    1    23
# 24                      6              0      1    2     0
# 25                      6              1      1    2     1
# 26                      6              2      1    2     2
# 27                      6              3      1    2     3
# 28                      6              4      1    2     4
# 29                      6              6      1    2     6
# ...                   ...            ...    ...  ...   ...
# 10856                   1             18     12   18    18
# 10857                   1             19     12   18    19
# 10858                   1             20     12   18    20
# 10859                   1             21     12   18    21
# 10860                   1             22     12   18    22
# 10861                   1             23     12   18    23
# 10862                   2              0     12   19     0
# 10863                   2              1     12   19     1
# 10864                   2              2     12   19     2
# 10865                   2              3     12   19     3
# 10866                   2              4     12   19     4
# 10867                   2              5     12   19     5
# 10868                   2              6     12   19     6
# 10869                   2              7     12   19     7
# 10870                   2              8     12   19     8
# 10871                   2              9     12   19     9
# 10872                   2             10     12   19    10
# 10873                   2             11     12   19    11
# 10874                   2             12     12   19    12
# 10875                   2             13     12   19    13
# 10876                   2             14     12   19    14
# 10877                   2             15     12   19    15
# 10878                   2             16     12   19    16
# 10879                   2             17     12   19    17
# 10880                   2             18     12   19    18
# 10881                   2             19     12   19    19
# 10882                   2             20     12   19    20
# 10883                   2             21     12   19    21
# 10884                   2             22     12   19    22
# 10885                   2             23     12   19    23
#
# [10886 rows x 17 columns]

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  ...  count  datetime-year  datetime-month  \
# 0        81        0.0       3  ...     16           2011               1
# 1        80        0.0       8  ...     40           2011               1
# 2        80        0.0       5  ...     32           2011               1
# 3        75        0.0       3  ...     13           2011               1
# 4        75        0.0       0  ...      1           2011               1
#
#    datetime-day  datetime-dayofweek  datetime-dayofwek datetime-hour  month  \
# 0             1                   5                sat             0      1
# 1             1                   5                sat             1      1
# 2             1                   5                sat             2      1
# 3             1                   5                sat             3      1
# 4             1                   5                sat             4      1
#
#    day  hour
# 0    1     0
# 1    1     1
# 2    1     2
# 3    1     3
# 4    1     4
#
# [5 rows x 21 columns]

# %%
figure, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2, ncols=2)
figure.set_size_inches(18,8)

sns.barplot(data=train, x="year",y="count", ax=ax1)
sns.barplot(data=train, x="month",y="count", ax=ax2)
sns.barplot(data=train, x="day",y="count", ax=ax3)
sns.barplot(data=train, x="hour",y="count", ax=ax4)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_size_inches(12,10)
sns.boxplot(data=train,y="count",orient="v",ax=axes[0][0])
sns.boxplot(data=train,y="count",x="season",ax=axes[0][1])
sns.boxplot(data=train,y="count",x="hour",ax=axes[1][0])
sns.boxplot(data=train,y="count",x="workingday",ax=axes[1][1])

# %%
sns.barplot(data=train, x="holiday",y="count")

# %%
train["dayofweek"] = train["datetime"].dt.dayofweek
train.shape
# Out:
# (10886, 23)

# %%
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5)
fig.set_size_inches(18,25)

sns.pointplot(data=train, x="hour", y="count", ax=ax1)
sns.pointplot(data=train, x="hour", y="count",hue="workingday", ax=ax2)
sns.pointplot(data=train, x="hour", y="count",hue="dayofweek", ax=ax3)
sns.pointplot(data=train, x="hour", y="count",hue="weather", ax=ax4)
sns.pointplot(data=train, x="hour", y="count",hue="season", ax=ax5)

# %%
corrMatt = train[["temp","atemp","casual","registered","humidity","windspeed","count"]]
corrMatt = corrMatt.corr()
print(corrMatt)
# Out:
#                 temp     atemp    casual  registered  humidity  windspeed  \
# temp        1.000000  0.984948  0.467097    0.318571 -0.064949  -0.017852
# atemp       0.984948  1.000000  0.462067    0.314635 -0.043536  -0.057473
# casual      0.467097  0.462067  1.000000    0.497250 -0.348187   0.092276
# registered  0.318571  0.314635  0.497250    1.000000 -0.265458   0.091052
# humidity   -0.064949 -0.043536 -0.348187   -0.265458  1.000000  -0.318607
# windspeed  -0.017852 -0.057473  0.092276    0.091052 -0.318607   1.000000
# count       0.394454  0.389784  0.690414    0.970948 -0.317371   0.101369
#
#                count
# temp        0.394454
# atemp       0.389784
# casual      0.690414
# registered  0.970948
# humidity   -0.317371
# windspeed   0.101369
# count       1.000000

# %%
fig,(ax1,ax2,ax3) = plt.subplots(ncols=3)
fig.set_size_inches(12,5)
sns.regplot(x='temp', y='count', data=train,ax=ax1)
sns.regplot(x='windspeed', y='count', data=train,ax=ax2)
sns.regplot(x='humidity', y='count', data=train,ax=ax3)
# Out:
# L:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def concatenate_year_month(datetime):
    return "{0}-{1}".format(datetime.year, datetime.month)

train["year_month"] = train["datetime"].apply(concatenate_year_month)

print(train.shape)
train["year_month"].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-208-8a5c793b8317> in <module>
#       2     return "{0}-{1}".format(datetime.year, datetime.month)
#       3
# ----> 4 train["year_month"] = train["datetime"].apply(concatenate_year_month)
#       5
#       6 print(train.shape)
#
# L:\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-208-8a5c793b8317> in concatenate_year_month(datetime)
#       1 def concatenate_year_month(datetime):
# ----> 2     return "{0}-{1}".format(datetime.year, datetime.month)
#       3
#       4 train["year_month"] = train["datetime"].apply(concatenate_year_month)
#       5
#
# AttributeError: 'str' object has no attribute 'year'

# %%
fig.set_size_inches(100,50)
sns.barplot(data=train, x="year_month",y="count")

# %%
trainNoOutlier = train[np.abs(train["count"] - train["count"].mean()) <= (3*train["count"])]
print(trainNoOutlier.shape)
# Out:
# (8001, 12)
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# 5      2011-01-01 05:00:00       1        0           0        2   9.84
# 6      2011-01-01 06:00:00       1        0           0        1   9.02
# 7      2011-01-01 07:00:00       1        0           0        1   8.20
# 8      2011-01-01 08:00:00       1        0           0        1   9.84
# 9      2011-01-01 09:00:00       1        0           0        1  13.12
# 10     2011-01-01 10:00:00       1        0           0        1  15.58
# 11     2011-01-01 11:00:00       1        0           0        1  14.76
# 12     2011-01-01 12:00:00       1        0           0        1  17.22
# 13     2011-01-01 13:00:00       1        0           0        2  18.86
# 14     2011-01-01 14:00:00       1        0           0        2  18.86
# 15     2011-01-01 15:00:00       1        0           0        2  18.04
# 16     2011-01-01 16:00:00       1        0           0        2  17.22
# 17     2011-01-01 17:00:00       1        0           0        2  18.04
# 18     2011-01-01 18:00:00       1        0           0        3  17.22
# 19     2011-01-01 19:00:00       1        0           0        3  17.22
# 20     2011-01-01 20:00:00       1        0           0        2  16.40
# 21     2011-01-01 21:00:00       1        0           0        2  16.40
# 22     2011-01-01 22:00:00       1        0           0        2  16.40
# 23     2011-01-01 23:00:00       1        0           0        2  18.86
# 24     2011-01-02 00:00:00       1        0           0        2  18.86
# 25     2011-01-02 01:00:00       1        0           0        2  18.04
# 26     2011-01-02 02:00:00       1        0           0        2  17.22
# 27     2011-01-02 03:00:00       1        0           0        2  18.86
# 28     2011-01-02 04:00:00       1        0           0        2  18.86
# 29     2011-01-02 06:00:00       1        0           0        3  17.22
# ...                    ...     ...      ...         ...      ...    ...
# 10856  2012-12-18 18:00:00       4        0           1        1  15.58
# 10857  2012-12-18 19:00:00       4        0           1        1  15.58
# 10858  2012-12-18 20:00:00       4        0           1        1  14.76
# 10859  2012-12-18 21:00:00       4        0           1        1  14.76
# 10860  2012-12-18 22:00:00       4        0           1        1  13.94
# 10861  2012-12-18 23:00:00       4        0           1        1  13.94
# 10862  2012-12-19 00:00:00       4        0           1        1  12.30
# 10863  2012-12-19 01:00:00       4        0           1        1  12.30
# 10864  2012-12-19 02:00:00       4        0           1        1  11.48
# 10865  2012-12-19 03:00:00       4        0           1        1  10.66
# 10866  2012-12-19 04:00:00       4        0           1        1   9.84
# 10867  2012-12-19 05:00:00       4        0           1        1  10.66
# 10868  2012-12-19 06:00:00       4        0           1        1   9.84
# 10869  2012-12-19 07:00:00       4        0           1        1  10.66
# 10870  2012-12-19 08:00:00       4        0           1        1   9.84
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-9ace9248e1b3> in <module>
#       1 figure, (ax1,ax2) = plt.subplots(ncols=2)
#       2 figure.set_size_inches(12,10)
# ----> 3 train.head()
#       4 sns.distplot(np.log(train["count"]),ax = ax1 )
#       5 sns.distplot(np.log(trainNoOutlier["count"]),ax = ax2)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
sns.countplot(data=train,x="windspeed")

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=train,x="windspeed")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
def predict_windspeed(data):
    dataWind0 = data.loc[data['windspeed'] == 0]
    dataWind0.head()
    dataWindNot0 = data.loc[data['windspeed'] != 0]
    wCol = ["season", "weather", "humidity", "month", "year", "atemp"]
    dataWindNot0["windspeed"] = dataWindNot0["windspeed"].astype("str")
    rfModel_wind = RandomForestClassifier()
    rfModel_wind.fit(dataWindNot0[wCol], dataWindNot0["windspeed"])
    #print(rfModel_wind)
   
    wind0Values = rfModel_wind.predict(X = dataWind0[wCol])
   
    predictWind0 = dataWind0
    predictWindNot0 = dataWindNot0
    
    predictWind0["windspeed"] = wind0Values
    data = predictWindNot0.append(predictWind0)
    data["windspeed"] = data["windspeed"].astype("float")
    
    data.reset_index(inplace=True)
    data.drop('index', inplace=True, axis=1)
    
    return data

# %%
train = predict_windspeed(train)
train["windspeed"].describe()
# Out:
# L:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# L:\Anaconda\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# L:\Anaconda\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# count    10886.000000
# mean        14.102550
# std          7.006904
# min          6.003200
# 25%          8.998100
# 50%         12.998000
# 75%         19.001200
# max         56.996900
# Name: windspeed, dtype: float64

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=train,x="windspeed")
plt.show()

# %%
train = pd.read_csv("train.csv", parse_dates=["datetime"])
test = pd.read_csv("test.csv", parse_dates=["datetime"])

print(train.head())
train["year"] = train["datetime"].dt.year
train["month"] = train["datetime"].dt.month
train["day"] = train["datetime"].dt.day
train["hour"] = train["datetime"].dt.hour

test["year"] = test["datetime"].dt.year
test["month"] = test["datetime"].dt.month
test["day"] = test["datetime"].dt.day
test["hour"] = test["datetime"].dt.hour
#print(test.describe())
label = 'count'
Y_train = train[label]
Y_test = test[label]

category_names =["season","holiday","workingday","weather","month","year","hour"]

for var in category_names:
    train[var] = train[var].astype("category")
    test[var] = test[var].astype("category")
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# L:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-324-cfa3210c5463> in <module>
#      15 label = 'count'
#      16 Y_train = train[label]
# ---> 17 Y_test = test[label]
#      18
#      19 category_names =["season","holiday","workingday","weather","month","year","hour"]
#
# L:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# L:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'

# %%
feature_name=['season','weather','temp','windspeed','year','hour','holiday']

# %%
N_train = train[feature_name]
N_train.head()
# Out:
#   season weather  temp  windspeed  year hour holiday
# 0      1       1  9.84        0.0  2011    0       0
# 1      1       1  9.02        0.0  2011    1       0
# 2      1       1  9.02        0.0  2011    2       0
# 3      1       1  9.84        0.0  2011    3       0
# 4      1       1  9.84        0.0  2011    4       0

# %%
N_test = test[feature_name]
print(test)

train = pd.read_csv("train.csv", parse_dates=["datetime"])
test = pd.read_csv("test.csv", parse_dates=["datetime"])

print(train.head())
train["year"] = train["datetime"].dt.year
train["month"] = train["datetime"].dt.month
train["day"] = train["datetime"].dt.day
train["hour"] = train["datetime"].dt.hour

test["year"] = test["datetime"].dt.year
test["month"] = test["datetime"].dt.month
test["day"] = test["datetime"].dt.day
test["hour"] = test["datetime"].dt.hour
#print(test.describe())
label = 'count'
Y_train = train[label]
Y_test = test[label]
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 0    2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 5    2011-01-20 05:00:00       1        0           1        1   9.84  11.365
# 6    2011-01-20 06:00:00       1        0           1        1   9.02  10.605
# 7    2011-01-20 07:00:00       1        0           1        1   9.02  10.605
# 8    2011-01-20 08:00:00       1        0           1        1   9.02  10.605
# 9    2011-01-20 09:00:00       1        0           1        2   9.84  11.365
# 10   2011-01-20 10:00:00       1        0           1        1  10.66  11.365
# 11   2011-01-20 11:00:00       1        0           1        2  11.48  13.635
# 12   2011-01-20 12:00:00       1        0           1        2  12.30  16.665
# 13   2011-01-20 13:00:00       1        0           1        2  11.48  14.395
# 14   2011-01-20 14:00:00       1        0           1        2  12.30  15.150
# 15   2011-01-20 15:00:00       1        0           1        2  13.12  15.910
# 16   2011-01-20 16:00:00       1        0           1        2  12.30  15.150
# 17   2011-01-20 17:00:00       1        0           1        2  12.30  15.910
# 18   2011-01-20 18:00:00       1        0           1        2  10.66  12.880
# 19   2011-01-20 19:00:00       1        0           1        1  10.66  11.365
# 20   2011-01-20 20:00:00       1        0           1        2  10.66  12.120
# 21   2011-01-20 21:00:00       1        0           1        2   9.84  11.365
# 22   2011-01-20 22:00:00       1        0           1        2   9.84  10.605
# 23   2011-01-20 23:00:00       1        0           1        2   9.84  10.605
# 24   2011-01-21 00:00:00       1        0           1        2   9.84  11.365
# 25   2011-01-21 01:00:00       1        0           1        2   9.84  11.365
# 26   2011-01-21 02:00:00       1        0           1        3   9.84  12.120
# 27   2011-01-21 03:00:00       1        0           1        3   9.02  10.605
# 28   2011-01-21 04:00:00       1        0           1        2   9.02  12.880
# 29   2011-01-21 05:00:00       1        0           1        1   9.84   9.850
# ...                  ...     ...      ...         ...      ...    ...     ...
# 6463 2012-12-30 18:00:00       1        0           0        2   9.84  10.605
# 6464 2012-12-30 19:00:00       1        0           0        1  13.94  18.180
# 6465 2012-12-30 20:00:00       1        0           0        1   9.02   9.850
# 6466 2012-12-30 21:00:00       1        0           0        1   8.20  10.605
# 6467 2012-12-30 22:00:00       1        0           0        1   8.20   9.850
# 6468 2012-12-30 23:00:00       1        0           0        1   8.20   9.850
# 6469 2012-12-31 00:00:00       1        0           1        1   7.38   9.090
# 6470 2012-12-31 01:00:00       1        0           1        1   7.38   9.090
# 6471 2012-12-31 02:00:00       1        0           1        1   6.56   8.335
# 6472 2012-12-31 03:00:00       1        0           1        1   6.56   9.090
# 6473 2012-12-31 04:00:00       1        0           1        1   5.74   8.335
# 6471        59    11.0014  2012     12   31     2
# 6472        59     7.0015  2012     12   31     3
# 6473        69     7.0015  2012     12   31     4
# 6474        64    12.9980  2012     12   31     5
# 6475        64    11.0014  2012     12   31     6
# 6476        64     8.9981  2012     12   31     7
# 6477        69     8.9981  2012     12   31     8
# 6478        64     7.0015  2012     12   31     9
# 6479        69     8.9981  2012     12   31    10
# 6480        60    12.9980  2012     12   31    11
# 6481        56    12.9980  2012     12   31    12
# 6482        44    11.0014  2012     12   31    13
# 6483        45    15.0013  2012     12   31    14
# 6484        45     8.9981  2012     12   31    15
# 6485        48    12.9980  2012     12   31    16
# 6486        48     6.0032  2012     12   31    17
# 6487        48     8.9981  2012     12   31    18
# 6488        60    11.0014  2012     12   31    19
# 6489        60    11.0014  2012     12   31    20
# 6490        60    11.0014  2012     12   31    21
# 6491        56     8.9981  2012     12   31    22
# 6492        65     8.9981  2012     12   31    23
#
# [6493 rows x 13 columns]
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# L:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-337-199d5325c574> in <module>
#      18 label = 'count'
#      19 Y_train = train[label]
# ---> 20 Y_test = test[label]
#
# L:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# L:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'

# %%
from sklearn.metrics import make_scorer

# %%
def rmsle(predict_v, actual_v):
    predict_v = np.array(predict_v)
    actual_v = np.array(actual_v)
    
    log_predict = np.log(predict_v +1)
    log_actual = np.log(actual_v +1)
    
    difference = log_predict - log_actual
    difference = np.square(difference)
    
    mean_difference = difference.mean()
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

max_dep_list = []

model = RandomForestRegressor(n_estimators=100,
                             n_jobs=-1,
                             random_state=0)

# %%
# %time score = cross_val_score(model, N_train, Y_train, cv=k_fold, scoring=rmsle_scorer)
score = score.mean()
print("score= {0:.5f}".format(score))
# Out:
# Wall time: 13.9 s
# score= 0.63462

# %%
model.fit(N_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
prediction = model.predict(N_test)
print(prediction.shape)
prediction[0:10]
# Out:
# (6493,)
# array([24.17      , 13.77316667, 14.08985714,  6.81      ,  1.88885714,
#         6.58      , 25.992     , 76.56      , 82.47      , 64.36      ])

# %%
sns.distplot(Y_train,bins=50)
sns.distplot(Y_test,bins=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-343-54d2af0acb31> in <module>
#       1 sns.distplot(Y_train,bins=50)
# ----> 2 sns.distplot(Y_test,bins=50)
#
# NameError: name 'Y_test' is not defined

# %%
submission = pd.read_csv("sampleSubmission.csv")

# %%
submission["count"] = prediction
submission.head()
# Out:
#               datetime      count
# 0  2011-01-20 00:00:00  24.170000
# 1  2011-01-20 01:00:00  13.773167
# 2  2011-01-20 02:00:00  14.089857
# 3  2011-01-20 03:00:00   6.810000
# 4  2011-01-20 04:00:00   1.888857

# %%
submission.to_csv("Score_{0:.5f}_submission.csv".format(score), index =False)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)

lModel = LinearRegression()

y_train_log = np.log1p(Y_train)
lModel.fit(N_train,y_train_log)

preds = lModel.predict(N_train)
print(rmsle(np.exp(y_train_log),np.exp(preds)))
# Out:
# 1.0049645025626732
